# %% [markdown]
# <a href="https://colab.research.google.com/github/2023-106650-sketch/Sklearn/blob/main/Copy_of_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# use word pip to install sklearn in python
# !pip install scikit-learn

# %%
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


X, y = make_classification(n_samples=99, n_features=4, random_state=22)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=22)


model = DecisionTreeClassifier(max_depth=3, random_state=22)
model.fit(X_train, y_train)


y_pred = model.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9666666666666667
